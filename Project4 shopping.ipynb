# %%
import pandas as pd
import datetime as dt

# %%
file = "customer_shopping_data.csv"
shopping = pd.read_csv(file)

# %%
shopping.head(5)
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date  Unnamed: 9   shopping_mall
# 0    Credit Card     5/8/2022         NaN          Kanyon
# 1     Debit Card   12/12/2021         NaN  Forum Istanbul
# 2           Cash    9/11/2021         NaN       Metrocity
# 3    Credit Card   16/05/2021         NaN    Metropol AVM
# 4           Cash   24/10/2021         NaN          Kanyon

# %%
shopping.drop(columns = "Unnamed: 9", inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18980\1883138374.py in <module>
# ----> 1 shopping.drop(columns = "Unnamed: 9", inplace = True)
#       2 shopping.head()
#
# D:\school files\Certificate course\anaconda\envs\PythonData\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# D:\school files\Certificate course\anaconda\envs\PythonData\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# D:\school files\Certificate course\anaconda\envs\PythonData\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# D:\school files\Certificate course\anaconda\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['Unnamed: 9'] not found in axis"

# %%
shopping.head(25)
# Out:
#    invoice_no customer_id  gender  age         category  quantity    price  \
# 0     I138884     C241288  Female   28         Clothing         5  1500.40
# 1     I317333     C111565    Male   21            Shoes         3  1800.51
# 2     I127801     C266599    Male   20         Clothing         1   300.08
# 3     I173702     C988172  Female   66            Shoes         5  3000.85
# 4     I337046     C189076  Female   53            Books         4    60.60
# 5     I227836     C657758  Female   28         Clothing         5  1500.40
# 6     I121056     C151197  Female   49        Cosmetics         1    40.66
# 7     I293112     C176086  Female   32         Clothing         2   600.16
# 8     I293455     C159642    Male   69         Clothing         3   900.24
# 9     I326945     C283361  Female   60         Clothing         2   600.16
# 10    I306368     C240286  Female   36  Food & Beverage         2    10.46
# 11    I139207     C191708  Female   29            Books         1    15.15
# 12    I640508     C225330  Female   67             Toys         4   143.36
# 13    I179802     C312861    Male   25         Clothing         2   600.16
# 14    I336189     C555402  Female   67         Clothing         2   600.16
# 15    I688768     C362288    Male   24            Shoes         5  3000.85
# 16    I294687     C300786    Male   65            Books         2    30.30
# 17    I195744     C330667  Female   42  Food & Beverage         3    15.69
# 18    I993048     C218149  Female   46         Clothing         2   600.16
# 19    I992454     C196845    Male   24             Toys         4   143.36
# 20    I183746     C220180    Male   23         Clothing         1   300.08
# 21    I412481     C125696  Female   27  Food & Beverage         1     5.23
# 22    I823067     C322947    Male   52         Clothing         2   600.16
# 23    I252275     C313348    Male   44       Technology         5  5250.00
# 24    I174250     C204553  Female   42            Books         5    75.75
#
#    payment_method invoice_date      shopping_mall
# 0     Credit Card     5/8/2022             Kanyon
# 1      Debit Card   12/12/2021     Forum Istanbul
# 2            Cash    9/11/2021          Metrocity
# 3     Credit Card   16/05/2021       Metropol AVM
# 4            Cash   24/10/2021             Kanyon
# 5     Credit Card   24/05/2022     Forum Istanbul
# 6            Cash   13/03/2022       Istinye Park
# 7     Credit Card   13/01/2021   Mall of Istanbul
# 8     Credit Card    4/11/2021          Metrocity
# 9     Credit Card   22/08/2021             Kanyon
# 10           Cash   25/12/2022          Metrocity
# 11    Credit Card   28/10/2022  Emaar Square Mall
# 12     Debit Card   31/07/2022          Metrocity
# 13           Cash   17/11/2022        Cevahir AVM
# 14    Credit Card     3/6/2022             Kanyon
# 15    Credit Card    7/11/2021     Viaport Outlet
# 16     Debit Card   16/01/2021          Metrocity
# 17    Credit Card     5/1/2022       Zorlu Center
# 18           Cash   26/07/2021       Metropol AVM
# 19           Cash     7/3/2023        Cevahir AVM
# 20    Credit Card   15/02/2023  Emaar Square Mall
# 21           Cash     1/5/2021        Cevahir AVM
# 22    Credit Card   18/06/2022        Cevahir AVM
# 23           Cash   26/10/2021             Kanyon
# 24           Cash   16/12/2022          Metrocity

# %%
shopping.invoice_date = pd.to_datetime(shopping.invoice_date)
shopping['Day of week'] = shopping.invoice_date.dt.dayofweek
shopping.head(25)
# Out:
#     gender  age         category  quantity    price payment_method  \
# 0   Female   28         Clothing         5  1500.40    Credit Card
# 1     Male   21            Shoes         3  1800.51     Debit Card
# 2     Male   20         Clothing         1   300.08           Cash
# 3   Female   66            Shoes         5  3000.85    Credit Card
# 4   Female   53            Books         4    60.60           Cash
# 5   Female   28         Clothing         5  1500.40    Credit Card
# 6   Female   49        Cosmetics         1    40.66           Cash
# 7   Female   32         Clothing         2   600.16    Credit Card
# 8     Male   69         Clothing         3   900.24    Credit Card
# 9   Female   60         Clothing         2   600.16    Credit Card
# 10  Female   36  Food & Beverage         2    10.46           Cash
# 11  Female   29            Books         1    15.15    Credit Card
# 12  Female   67             Toys         4   143.36     Debit Card
# 13    Male   25         Clothing         2   600.16           Cash
# 14  Female   67         Clothing         2   600.16    Credit Card
# 15    Male   24            Shoes         5  3000.85    Credit Card
# 16    Male   65            Books         2    30.30     Debit Card
# 17  Female   42  Food & Beverage         3    15.69    Credit Card
# 18  Female   46         Clothing         2   600.16           Cash
# 19    Male   24             Toys         4   143.36           Cash
# 20    Male   23         Clothing         1   300.08    Credit Card
# 21  Female   27  Food & Beverage         1     5.23           Cash
# 22    Male   52         Clothing         2   600.16    Credit Card
# 23    Male   44       Technology         5  5250.00           Cash
# 24  Female   42            Books         5    75.75           Cash
#
#    invoice_date      shopping_mall  Day of week
# 0    2022-05-08             Kanyon            6
# 1    2021-12-12     Forum Istanbul            6
# 2    2021-09-11          Metrocity            5
# 3    2021-05-16       Metropol AVM            6
# 4    2021-10-24             Kanyon            6
# 5    2022-05-24     Forum Istanbul            1
# 6    2022-03-13       Istinye Park            6
# 7    2021-01-13   Mall of Istanbul            2
# 8    2021-04-11          Metrocity            6
# 9    2021-08-22             Kanyon            6
# 10   2022-12-25          Metrocity            6
# 11   2022-10-28  Emaar Square Mall            4
# 12   2022-07-31          Metrocity            6
# 13   2022-11-17        Cevahir AVM            3
# 14   2022-03-06             Kanyon            6
# 15   2021-07-11     Viaport Outlet            6
# 16   2021-01-16          Metrocity            5
# 17   2022-05-01       Zorlu Center            6
# 18   2021-07-26       Metropol AVM            0
# 19   2023-07-03        Cevahir AVM            0
# 20   2023-02-15  Emaar Square Mall            2
# 21   2021-01-05        Cevahir AVM            1
# 22   2022-06-18        Cevahir AVM            5
# 23   2021-10-26             Kanyon            1
# 24   2022-12-16          Metrocity            4

# %%
shopping.dtypes
# Out:
# invoice_no                object
# customer_id               object
# gender                    object
# age                        int64
# category                  object
# quantity                   int64
# price                    float64
# payment_method            object
# invoice_date      datetime64[ns]
# shopping_mall             object
# dtype: object

# %%
shopping.drop(columns = ['invoice_no', 'US Date','customer_id'], inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18980\4203891135.py in <module>
# ----> 1 shopping.drop(columns = ['invoice_no', 'US Date','customer_id'], inplace = True)
#       2 shopping.head()
#
# D:\school files\Certificate course\anaconda\envs\PythonData\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# D:\school files\Certificate course\anaconda\envs\PythonData\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# D:\school files\Certificate course\anaconda\envs\PythonData\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# D:\school files\Certificate course\anaconda\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['invoice_no' 'US Date' 'customer_id'] not found in axis"

# %%
shopping.head()
# Out:
#    gender  age  category  quantity    price payment_method invoice_date  \
# 0  Female   28  Clothing         5  1500.40    Credit Card   2022-05-08
# 1    Male   21     Shoes         3  1800.51     Debit Card   2021-12-12
# 2    Male   20  Clothing         1   300.08           Cash   2021-09-11
# 3  Female   66     Shoes         5  3000.85    Credit Card   2021-05-16
# 4  Female   53     Books         4    60.60           Cash   2021-10-24
#
#     shopping_mall  Day of week
# 0          Kanyon            6
# 1  Forum Istanbul            6
# 2       Metrocity            5
# 3    Metropol AVM            6
# 4          Kanyon            6

# %%
stuff = shopping[["Day of week",'age']]
stuff
# Out:
#        Day of week  age
# 0                6   28
# 1                6   21
# 2                5   20
# 3                6   66
# 4                6   53
# ...            ...  ...
# 99452            2   45
# 99453            2   27
# 99454            6   63
# 99455            1   56
# 99456            5   36
#
# [99457 rows x 2 columns]

# %%
one_hot_encoded = pd.get_dummies(stuff, columns = ['Day of week'])
one_hot_encoded
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18980\993515432.py in <module>
# ----> 1 one_hot_encoded = pd.get_dummies(stuff, columns = ['Sunday','Saturday','Tuesday','Wednesday','Friday','Thursday','Monday'])
#       2 one_hot_encoded
#
# D:\school files\Certificate course\anaconda\envs\PythonData\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     866             raise TypeError("Input must be a list-like for parameter `columns`")
#     867         else:
# --> 868             data_to_encode = data[columns]
#     869
#     870         # validate prefixes and separator to avoid silently dropping cols
#
# D:\school files\Certificate course\anaconda\envs\PythonData\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# D:\school files\Certificate course\anaconda\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# D:\school files\Certificate course\anaconda\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1638             if missing == len(indexer):
#    1639                 axis_name = self.obj._get_axis_name(axis)
# -> 1640                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1641
#    1642             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['Sunday', 'Saturday', 'Tuesday', 'Wednesday', 'Friday', 'Thursday',\n       'Monday'],\n      dtype='object')] are in the [columns]"
